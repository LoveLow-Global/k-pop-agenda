# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
from urllib.parse import quote
from datetime import datetime, timedelta

# %%
# --- MANUAL CONFIGURATION ---
# Set your exact search query here. 
# The space acts as an AND operator in DCInside search.
COMPOUND_KEYWORD = "김광규" 

# Set the target date based on the article's publication
MIDDLE_DATE_STR = "2025-03-24-22-53"  # YYYY-MM-DD-HH-MM
middle_dt = datetime.strptime(MIDDLE_DATE_STR, "%Y-%m-%d-%H-%M")

# Time window calculation
calculated_start_dt = middle_dt - timedelta(days=15)
calculated_end_dt = middle_dt + timedelta(days=60)

calculated_start_dt = datetime.strptime("2025-09-01-00-00", "%Y-%m-%d-%H-%M")
calculated_end_dt = datetime.strptime("2026-04-30-23-59", "%Y-%m-%d-%H-%M")
START_DATE_STR = calculated_start_dt.strftime("%Y-%m-%d-%H-%M")
END_DATE_STR = calculated_end_dt.strftime("%Y-%m-%d-%H-%M")

# Update output filename to use the compound keyword, replacing spaces with underscores
safe_filename_keyword = COMPOUND_KEYWORD.replace(" ", "_")
OUTPUT_FILE = f"{safe_filename_keyword}_list.csv"

print(f"Target Query: '{COMPOUND_KEYWORD}'")
print(f"Time Window: {START_DATE_STR} to {END_DATE_STR}")
print(f"Output File: {OUTPUT_FILE}")
# Out:
# Target Query: '김광규'
# Time Window: 2025-09-01-00-00 to 2026-04-30-23-59
# Output File: 김광규_list.csv

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

def get_custom_encoded_keyword(keyword):
    """
    Converts '김종국 결혼식' -> '.EA.B9.80.EC.A2.85.EA.B5.AD.20.EA.B2.B0.ED.98.BC.EC.8B.9D'
    Standard URL encode uses %, DC Inside uses . for paths.
    """
    encoded = quote(keyword.encode('utf-8')).replace('%', '.')
    return encoded

def parse_date_arg(date_str):
    """Parses input string 'YYYY-MM-DD-HH-MM' to datetime object."""
    return datetime.strptime(date_str, "%Y-%m-%d-%H-%M")

def parse_article_date(date_text):
    """Parses article date '2025.12.28 10:41' to datetime object."""
    return datetime.strptime(date_text, "%Y.%m.%d %H:%M")

# %%
def scrape_dcinside():
    start_dt = parse_date_arg(START_DATE_STR)
    end_dt = parse_date_arg(END_DATE_STR)
    
    encoded_keyword = get_custom_encoded_keyword(COMPOUND_KEYWORD)
    
    # Dictionary to store unique posts. Key: Title, Value: Row Data
    unique_posts = {}
    
    page = 1
    stop_scraping = False
    
    while not stop_scraping:
        url = f"https://search.dcinside.com/post/p/{page}/sort/latest/q/{encoded_keyword}"
        print(f"Scanning Page {page}: {url}")
        
        try:
            response = requests.get(url, headers=HEADERS)
            if response.status_code != 200:
                print(f"Error: Status code {response.status_code}")
                break
            
            soup = BeautifulSoup(response.text, 'html.parser')
            
            result_list = soup.select('ul.sch_result_list > li')
            
            if not result_list:
                print("No more results found.")
                break
            
            for li in result_list:
                date_element = li.select_one('.link_dsc_txt.dsc_sub .date_time')
                if not date_element:
                    continue
                    
                article_date_str = date_element.get_text(strip=True)
                try:
                    article_dt = parse_article_date(article_date_str)
                except ValueError:
                    print(f"Skipping date parse error: {article_date_str}")
                    continue

                if article_dt > end_dt:
                    continue
                    
                if article_dt < start_dt:
                    print(f"Reached date {article_dt}, which is older than start time. Stopping.")
                    stop_scraping = True
                    break
                
                link_tag = li.select_one('a.tit_txt')
                if link_tag:
                    title = link_tag.get_text(strip=True)
                    article_url = link_tag['href']
                    
                    # --- NEW ADDITION START ---
                    # Find the paragraph with the content preview
                    content_tag = li.select_one('p.link_dsc_txt')
                    # Extract the text. Using separator=' ' ensures words don't mash together
                    # when stripping out inner tags like <b>
                    content = content_tag.get_text(separator=' ', strip=True) if content_tag else ""
                    # --- NEW ADDITION END ---

                    # Because we scrape newest -> oldest, overwriting the dictionary 
                    # ensures the final saved value is the absolute oldest one.
                    # Note: 'content' is now added to the array
                    unique_posts[title] = [COMPOUND_KEYWORD, article_date_str, title, article_url, content]
        
        except Exception as e:
            print(f"An error occurred: {e}")
            break
        
        page += 1

        if page > 120:
            print("Reached the 120-page limit.")
            break
        
        time.sleep(0.5)

    # After scraping finishes, save the deduplicated results to the CSV
    with open(OUTPUT_FILE, mode='w', newline='', encoding='utf-8-sig') as f:
        writer = csv.writer(f)
        
        # --- NEW ADDITION START ---
        # Update the header to include the 'content' column
        writer.writerow(['keyword', 'time', 'title', 'URL', 'content'])
        # --- NEW ADDITION END ---
        
        # Sort the posts by date descending (newest first) to maintain a logical list order
        sorted_posts = sorted(unique_posts.values(), key=lambda x: x[1], reverse=True)
        writer.writerows(sorted_posts)
        
    print(f"Scraping finished. {len(sorted_posts)} unique posts saved to {OUTPUT_FILE}")

if __name__ == "__main__":
    scrape_dcinside()
# Out:
# Scanning Page 1: https://search.dcinside.com/post/p/1/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 2: https://search.dcinside.com/post/p/2/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 3: https://search.dcinside.com/post/p/3/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 4: https://search.dcinside.com/post/p/4/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 5: https://search.dcinside.com/post/p/5/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 6: https://search.dcinside.com/post/p/6/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 7: https://search.dcinside.com/post/p/7/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 8: https://search.dcinside.com/post/p/8/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 9: https://search.dcinside.com/post/p/9/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 10: https://search.dcinside.com/post/p/10/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 11: https://search.dcinside.com/post/p/11/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 12: https://search.dcinside.com/post/p/12/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 13: https://search.dcinside.com/post/p/13/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 14: https://search.dcinside.com/post/p/14/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 15: https://search.dcinside.com/post/p/15/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 16: https://search.dcinside.com/post/p/16/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 17: https://search.dcinside.com/post/p/17/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 18: https://search.dcinside.com/post/p/18/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 19: https://search.dcinside.com/post/p/19/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 20: https://search.dcinside.com/post/p/20/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 21: https://search.dcinside.com/post/p/21/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 22: https://search.dcinside.com/post/p/22/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 23: https://search.dcinside.com/post/p/23/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 24: https://search.dcinside.com/post/p/24/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 25: https://search.dcinside.com/post/p/25/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 26: https://search.dcinside.com/post/p/26/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 27: https://search.dcinside.com/post/p/27/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 28: https://search.dcinside.com/post/p/28/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 29: https://search.dcinside.com/post/p/29/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 30: https://search.dcinside.com/post/p/30/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 31: https://search.dcinside.com/post/p/31/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 32: https://search.dcinside.com/post/p/32/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 33: https://search.dcinside.com/post/p/33/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 34: https://search.dcinside.com/post/p/34/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 35: https://search.dcinside.com/post/p/35/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 36: https://search.dcinside.com/post/p/36/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 37: https://search.dcinside.com/post/p/37/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 38: https://search.dcinside.com/post/p/38/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 39: https://search.dcinside.com/post/p/39/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Scanning Page 40: https://search.dcinside.com/post/p/40/sort/latest/q/.EA.B9.80.EA.B4.91.EA.B7.9C
# Reached date 2025-08-31 21:57:00, which is older than start time. Stopping.
# Scraping finished. 929 unique posts saved to 김광규_list.csv

# %%
def scrape_dcinside():
    start_dt = parse_date_arg(START_DATE_STR)
    end_dt = parse_date_arg(END_DATE_STR)
    
    encoded_keyword = get_custom_encoded_keyword(COMPOUND_KEYWORD)
    
    # Dictionary to store unique posts. Key: Title, Value: Row Data
    unique_posts = {}
    
    page = 1
    stop_scraping = False
    
    while not stop_scraping:
        url = f"https://search.dcinside.com/post/p/{page}/sort/latest/q/{encoded_keyword}"
        print(f"Scanning Page {page}: {url}")
        
        try:
            response = requests.get(url, headers=HEADERS)
            if response.status_code != 200:
                print(f"Error: Status code {response.status_code}")
                break
            
            soup = BeautifulSoup(response.text, 'html.parser')
            
            result_list = soup.select('ul.sch_result_list > li')
            
            if not result_list:
                print("No more results found.")
                break
            
            for li in result_list:
                date_element = li.select_one('.link_dsc_txt.dsc_sub .date_time')
                if not date_element:
                    continue
                    
                article_date_str = date_element.get_text(strip=True)
                try:
                    article_dt = parse_article_date(article_date_str)
                except ValueError:
                    print(f"Skipping date parse error: {article_date_str}")
                    continue

                if article_dt > end_dt:
                    continue
                    
                if article_dt < start_dt:
                    print(f"Reached date {article_dt}, which is older than start time. Stopping.")
                    stop_scraping = True
                    break
                
                link_tag = li.select_one('a.tit_txt')
                if link_tag:
                    title = link_tag.get_text(strip=True)
                    article_url = link_tag['href']
                    
                    # Because we scrape newest -> oldest, overwriting the dictionary 
                    # ensures the final saved value is the absolute oldest one.
                    unique_posts[title] = [COMPOUND_KEYWORD, article_date_str, title, article_url]
        
        except Exception as e:
            print(f"An error occurred: {e}")
            break
        
        page += 1

        if page > 120:
            print("Reached the 120-page limit.")
            break
        
        time.sleep(0.5)

    # After scraping finishes, save the deduplicated results to the CSV
    with open(OUTPUT_FILE, mode='w', newline='', encoding='utf-8-sig') as f:
        writer = csv.writer(f)
        writer.writerow(['keyword', 'time', 'title', 'URL'])
        
        # Sort the posts by date descending (newest first) to maintain a logical list order
        sorted_posts = sorted(unique_posts.values(), key=lambda x: x[1], reverse=True)
        writer.writerows(sorted_posts)
        
    print(f"Scraping finished. {len(sorted_posts)} unique posts saved to {OUTPUT_FILE}")

if __name__ == "__main__":
    scrape_dcinside()
# Out:
# Scanning Page 1: https://search.dcinside.com/post/p/1/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 2: https://search.dcinside.com/post/p/2/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 3: https://search.dcinside.com/post/p/3/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 4: https://search.dcinside.com/post/p/4/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 5: https://search.dcinside.com/post/p/5/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 6: https://search.dcinside.com/post/p/6/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 7: https://search.dcinside.com/post/p/7/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 8: https://search.dcinside.com/post/p/8/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 9: https://search.dcinside.com/post/p/9/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 10: https://search.dcinside.com/post/p/10/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 11: https://search.dcinside.com/post/p/11/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 12: https://search.dcinside.com/post/p/12/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 13: https://search.dcinside.com/post/p/13/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 14: https://search.dcinside.com/post/p/14/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 15: https://search.dcinside.com/post/p/15/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 16: https://search.dcinside.com/post/p/16/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 17: https://search.dcinside.com/post/p/17/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 18: https://search.dcinside.com/post/p/18/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 19: https://search.dcinside.com/post/p/19/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 20: https://search.dcinside.com/post/p/20/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 21: https://search.dcinside.com/post/p/21/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page 22: https://search.dcinside.com/post/p/22/sort/latest/q/.EC.9E.A5.EB.8F.84.EC.97.B0
# Scanning Page